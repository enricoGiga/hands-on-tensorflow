# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
except Exception:
    pass

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

# %load_ext tensorboard

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "deep"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
if tf.test.gpu_device_name():
    print('Default GPU Device:{}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Default GPU Device:/device:GPU:0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5852837123963618988
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6302793728
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 16056210967639786589
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 2060 SUPER, pci bus id: 0000:65:00.0, compute capability: 7.5"
# ]

# %% [markdown]
# # Deep Learning on CIFAR10
#
# ### **a.**   Exercise: Build a DNN with 20 hidden layers of 100 neurons each (that's too many, but it's the point of this exercise). Use He initialization and the ELU activation function.

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.cifar10.load_data()

X_train = X_train_full[5000:]
y_train = y_train_full[5000:]
X_valid = X_train_full[:5000]
y_valid = y_train_full[:5000]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#  - ETA: 3s
# 170508288/170498071 [==============================] - 23s 0us/step

# %%
X_train.shape
# Out:
# (45000, 32, 32, 3)

# %%
[m for m in dir(keras.activations) if not m.startswith("_")]
# Out:
# ['deserialize',
#  'elu',
#  'exponential',
#  'gelu',
#  'get',
#  'hard_sigmoid',
#  'linear',
#  'relu',
#  'selu',
#  'serialize',
#  'sigmoid',
#  'softmax',
#  'softplus',
#  'softsign',
#  'swish',
#  'tanh']

# %%
[m for m in dir(keras.initializers) if not m.startswith("_")]
# Out:
# ['Constant',
#  'GlorotNormal',
#  'GlorotUniform',
#  'HeNormal',
#  'HeUniform',
#  'Identity',
#  'Initializer',
#  'LecunNormal',
#  'LecunUniform',
#  'Ones',
#  'Orthogonal',
#  'RandomNormal',
#  'RandomUniform',
#  'TruncatedNormal',
#  'VarianceScaling',
#  'Zeros',
#  'constant',
#  'deserialize',
#  'get',
#  'glorot_normal',
#  'glorot_uniform',
#  'he_normal',
#  'he_uniform',
#  'identity',
#  'lecun_normal',
#  'lecun_uniform',
#  'ones',
#  'orthogonal',
#  'random_normal',
#  'random_uniform',
#  'serialize',
#  'truncated_normal',
#  'variance_scaling',
#  'zeros']

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[32,32,3]))
for _ in range(20):
    model.add(keras.layers.Dense(100,
                                 activation="elu",
                                 kernel_initializer="he_normal"))

# %% [markdown]
# b.
# Exercise: Using Nadam optimization and early stopping, train the network on the CIFAR10 dataset. You can load it with keras.datasets.cifar10.load_data(). The dataset is composed of 60,000 32 × 32–pixel color images (50,000 for training, 10,000 for testing) with 10 classes, so you'll need a softmax output layer with 10 neurons. Remember to search for the right learning rate each time you change the model's architecture or hyperparameters.

# %%
model.add(keras.layers.Dense(10, activation="softmax"))

# %%
optimizer = keras.optimizers.Nadam(learning_rate=5e-5)
model.compile(loss="sparse_categorical_crossentropy",

              optimizer=optimizer,
              metrics=["accuracy"])

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=20)
model_checkpoint_cb = keras.callbacks.ModelCheckpoint("my_cifar10_model.h5", save_best_only=True)
run_index = 1 # increment every time you train the model
run_logdir = os.path.join(os.curdir, "my_cifar10_logs", "run_{:03d}".format(run_index))
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

# %%
model.fit(X_train, y_train, epochs=100,
          validation_data=(X_valid, y_valid),
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 1407/1407 [==============================] - 36s 23ms/step - loss: 3.9412 - accuracy: 0.1742 - val_loss: 2.1588 - val_accuracy: 0.2220
# Epoch 2/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 2.0627 - accuracy: 0.2445 - val_loss: 2.1327 - val_accuracy: 0.2392
# Epoch 3/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.9422 - accuracy: 0.2843 - val_loss: 1.9864 - val_accuracy: 0.2696
# Epoch 4/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.8654 - accuracy: 0.3165 - val_loss: 1.8998 - val_accuracy: 0.3264
# Epoch 5/100
# 1407/1407 [==============================] - 33s 23ms/step - loss: 1.8074 - accuracy: 0.3432 - val_loss: 1.8286 - val_accuracy: 0.3242
# Epoch 6/100
# 1407/1407 [==============================] - 33s 23ms/step - loss: 1.7541 - accuracy: 0.3643 - val_loss: 1.7525 - val_accuracy: 0.3704
# Epoch 7/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.7102 - accuracy: 0.3813 - val_loss: 1.7233 - val_accuracy: 0.3718
# Epoch 8/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.6691 - accuracy: 0.3979 - val_loss: 1.6914 - val_accuracy: 0.3868
# Epoch 9/100
# 1407/1407 [==============================] - 33s 23ms/step - loss: 1.6406 - accuracy: 0.4100 - val_loss: 1.6414 - val_accuracy: 0.4068
# Epoch 10/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.6155 - accuracy: 0.4195 - val_loss: 1.6976 - val_accuracy: 0.3864
# Epoch 11/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.5933 - accuracy: 0.4288 - val_loss: 1.6441 - val_accuracy: 0.4076
# Epoch 12/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.5711 - accuracy: 0.4396 - val_loss: 1.6150 - val_accuracy: 0.4228
# Epoch 13/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.5510 - accuracy: 0.4444 - val_loss: 1.6320 - val_accuracy: 0.4200
# Epoch 14/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.5358 - accuracy: 0.4491 - val_loss: 1.5770 - val_accuracy: 0.4394
# Epoch 15/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.5208 - accuracy: 0.4564 - val_loss: 1.6038 - val_accuracy: 0.4340
# Epoch 16/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.5041 - accuracy: 0.4597 - val_loss: 1.5937 - val_accuracy: 0.4278
# Epoch 17/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.4900 - accuracy: 0.4663 - val_loss: 1.5653 - val_accuracy: 0.4438
# Epoch 18/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.4748 - accuracy: 0.4714 - val_loss: 1.6006 - val_accuracy: 0.4350
# Epoch 19/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.4662 - accuracy: 0.4743 - val_loss: 1.5914 - val_accuracy: 0.4328
# Epoch 20/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.4529 - accuracy: 0.4810 - val_loss: 1.5753 - val_accuracy: 0.4346
# Epoch 21/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.4444 - accuracy: 0.4811 - val_loss: 1.5666 - val_accuracy: 0.4506
# Epoch 22/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.4314 - accuracy: 0.4851 - val_loss: 1.5406 - val_accuracy: 0.4508
# Epoch 23/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.4186 - accuracy: 0.4901 - val_loss: 1.5663 - val_accuracy: 0.4310
# Epoch 24/100
# 1407/1407 [==============================] - 33s 23ms/step - loss: 1.4082 - accuracy: 0.4956 - val_loss: 1.5464 - val_accuracy: 0.4478
# Epoch 25/100
# 1407/1407 [==============================] - 33s 23ms/step - loss: 1.3995 - accuracy: 0.4974 - val_loss: 1.5521 - val_accuracy: 0.4438
# Epoch 26/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.3871 - accuracy: 0.5034 - val_loss: 1.5483 - val_accuracy: 0.4484
# Epoch 27/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.3764 - accuracy: 0.5055 - val_loss: 1.5382 - val_accuracy: 0.4554
# Epoch 28/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.3698 - accuracy: 0.5075 - val_loss: 1.5317 - val_accuracy: 0.4626
# Epoch 29/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.3608 - accuracy: 0.5108 - val_loss: 1.5179 - val_accuracy: 0.4658
# Epoch 30/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.3511 - accuracy: 0.5138 - val_loss: 1.5861 - val_accuracy: 0.4462
# Epoch 31/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.3434 - accuracy: 0.5180 - val_loss: 1.5968 - val_accuracy: 0.4412
# Epoch 32/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.3386 - accuracy: 0.5177 - val_loss: 1.5244 - val_accuracy: 0.4550
# Epoch 33/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.3288 - accuracy: 0.5206 - val_loss: 1.5714 - val_accuracy: 0.4546
# Epoch 34/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.3189 - accuracy: 0.5287 - val_loss: 1.5511 - val_accuracy: 0.4676
# Epoch 35/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.3108 - accuracy: 0.5302 - val_loss: 1.5688 - val_accuracy: 0.4534
# Epoch 36/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.3023 - accuracy: 0.5317 - val_loss: 1.5283 - val_accuracy: 0.4624
# Epoch 37/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.2958 - accuracy: 0.5334 - val_loss: 1.5399 - val_accuracy: 0.4688
# Epoch 38/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.2892 - accuracy: 0.5366 - val_loss: 1.5295 - val_accuracy: 0.4684
# Epoch 39/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.2825 - accuracy: 0.5410 - val_loss: 1.5343 - val_accuracy: 0.4654
# Epoch 40/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.2731 - accuracy: 0.5438 - val_loss: 1.5513 - val_accuracy: 0.4644
# Epoch 41/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.2654 - accuracy: 0.5460 - val_loss: 1.5564 - val_accuracy: 0.4740
# Epoch 42/100
#  - ETA: 25s - loss: 1.2580 - accuracy: 0.5449
# Epoch 43/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.2527 - accuracy: 0.5500 - val_loss: 1.5718 - val_accuracy: 0.4624
# Epoch 44/100
#  - ETA: 16s - loss: 1.2423 - accuracy: 0.5529
# Epoch 45/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.2385 - accuracy: 0.5535 - val_loss: 1.5848 - val_accuracy: 0.4558
# Epoch 46/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.2329 - accuracy: 0.5550 - val_loss: 1.5430 - val_accuracy: 0.4686
# Epoch 47/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.2215 - accuracy: 0.5606 - val_loss: 1.5837 - val_accuracy: 0.4546
# Epoch 48/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.2147 - accuracy: 0.5624 - val_loss: 1.5592 - val_accuracy: 0.4696
# Epoch 49/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.2087 - accuracy: 0.5640 - val_loss: 1.5587 - val_accuracy: 0.4660

# %%
model = keras.models.load_model("my_cifar10_model.h5")

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 157/157 [==============================] - 1s 4ms/step - loss: 1.5179 - accuracy: 0.4658
# [1.5179187059402466, 0.4657999873161316]
